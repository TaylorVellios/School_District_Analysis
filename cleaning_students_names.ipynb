# %%
import pandas as pd

file_open = 'Resources\students_complete.csv'
students_df = pd.read_csv(file_open)
students_df
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
# TAYLOR METHOD - WITHOUT PANDAS

shitty_names = [i for i in students_df["student_name"] if len(i.split()) > 2]
shitty_names
# Out:
# ['Dr. Richard Scott',
#  'Dr. Jordan Carson',
#  'Madeline Snyder MD',
#  'Mr. Dylan Taylor MD',
#  'Dr. Scott Gill',
#  'Miss Madison Everett',
#  'Virginia Ramirez MD',
#  'Joseph Morales III',
#  'Angela Perkins DVM',
#  'Heather Allen MD',
#  'Luke Lowery MD',
#  'Dr. Larry Hines',
#  'Emily Cardenas MD',
#  'Mrs. Elizabeth Espinoza DDS',
#  'Mrs. Lisa Becker',
#  'Mr. Travis Young',
#  'Paula Fernandez DVM',
#  'Dr. Xavier Bell II',
#  'Andrew Hanson MD',
#  'Mr. Roberto Wright MD',
#  'Mr. Dale Miller',
#  'Mary Gonzalez DDS',
#  'Mrs. Cindy Brown',
#  'James White MD',
#  'Donald Gill DDS',
#  'Mrs. Catherine Williams MD',
#  'Ashley Caldwell MD',
#  'Mr. Jared Campbell',
#  'Michael Moreno PhD',
#  'Tara Parker MD',
#  'Shawn Williams DVM',
#  'Dr. Alicia Martinez',
#  'Mr. Timothy Anderson',
#  'Mrs. Paula Lee',
#  'Mr. Elijah Hall',
#  'Mr. Raymond Stone',
#  'John Dickerson MD',
#  'Mr. Alex Franklin',
#  'Mrs. Jessica Dunn',
#  'Mr. Michael Stevenson',
# ...

# %%
#----TO GET THE STUDENT NAMES INTO A LIST USING PANDAS--- USE .tolist() on the "student_names" column
#Module Style To Filter Names
names = students_df["student_name"].tolist()

names_to_fix = []
for i in names:
    if len(i.split()) > 2:
        names_to_fix.append(i)
        
names_to_fix
# Out:
# ['Dr. Richard Scott',
#  'Dr. Jordan Carson',
#  'Madeline Snyder MD',
#  'Mr. Dylan Taylor MD',
#  'Dr. Scott Gill',
#  'Miss Madison Everett',
#  'Virginia Ramirez MD',
#  'Joseph Morales III',
#  'Angela Perkins DVM',
#  'Heather Allen MD',
#  'Luke Lowery MD',
#  'Dr. Larry Hines',
#  'Emily Cardenas MD',
#  'Mrs. Elizabeth Espinoza DDS',
#  'Mrs. Lisa Becker',
#  'Mr. Travis Young',
#  'Paula Fernandez DVM',
#  'Dr. Xavier Bell II',
#  'Andrew Hanson MD',
#  'Mr. Roberto Wright MD',
#  'Mr. Dale Miller',
#  'Mary Gonzalez DDS',
#  'Mrs. Cindy Brown',
#  'James White MD',
#  'Donald Gill DDS',
#  'Mrs. Catherine Williams MD',
#  'Ashley Caldwell MD',
#  'Mr. Jared Campbell',
#  'Michael Moreno PhD',
#  'Tara Parker MD',
#  'Shawn Williams DVM',
#  'Dr. Alicia Martinez',
#  'Mr. Timothy Anderson',
#  'Mrs. Paula Lee',
#  'Mr. Elijah Hall',
#  'Mr. Raymond Stone',
#  'John Dickerson MD',
#  'Mr. Alex Franklin',
#  'Mrs. Jessica Dunn',
#  'Mr. Michael Stevenson',
# ...

# %%
# CREATE A LIST OF ALL PREFIXES THAT ARE 4 OR LESS CHARACTERS IN LENGTH

#TAYLOR MODE
# prefixes = [i.split()[0] for i in names_to_fix if len(i.split()[0]) <= 4]

prefix = []
for name in names_to_fix:
    if len(name.split()[0]) <= 4:
        prefix.append(name.split()[0])
prefix
# Out:
# ['Dr.',
#  'Dr.',
#  'Mr.',
#  'Dr.',
#  'Miss',
#  'Luke',
#  'Dr.',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mary',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Tara',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'John',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Dale',
#  'Dr.',
#  'Dr.',
#  'Dr.',
#  'Ms.',
#  'Dr.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Amy',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mrs.',
#  'Mrs.',
#  'Mr.',
#  'Lisa',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mark',
#  'Mrs.',
#  'Dr.',
#  'Dr.',
#  'Miss',
#  'Mr.',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
#  'Dr.',
#  'Dr.',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Tara',
#  'Dr.',
#  'Mr.',
#  'Cody',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Ms.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Sara',
#  'Mr.',
#  'Mrs.',
#  'Dr.',
#  'Mr.',
#  'Dr.',
#  'Mr.',
#  'Mrs.',
#  'Mr.',
#  'Mr.',
#  'Mr.',
# ...

# %%
# GET THE SUFFIXES NOW

#TAYLOR MODE
#suffixes = [i.split()[-1] for i in names_to_fix if len(i.split()[-1]) <= 3]

suffix = []
for name in names_to_fix:
    if len(name.split()[-1]) <= 3:
        suffix.append(name.split()[-1])
suffix
# Out:
# ['MD',
#  'MD',
#  'MD',
#  'III',
#  'DVM',
#  'MD',
#  'MD',
#  'MD',
#  'DDS',
#  'DVM',
#  'II',
#  'MD',
#  'MD',
#  'DDS',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'PhD',
#  'MD',
#  'DVM',
#  'Lee',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'MD',
#  'MD',
#  'MD',
#  'MD',
#  'DDS',
#  'Jr.',
#  'DVM',
#  'MD',
#  'MD',
#  'PhD',
#  'IV',
#  'MD',
#  'DDS',
#  'DDS',
#  'DDS',
#  'MD',
#  'DDS',
#  'MD',
#  'DVM',
#  'IV',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'DVM',
#  'Jr.',
#  'MD',
#  'PhD',
#  'II',
#  'MD',
#  'DDS',
#  'DDS',
#  'DDS',
#  'Jr.',
#  'III',
#  'MD',
#  'MD',
#  'MD',
#  'DDS',
#  'Jr.',
#  'DDS',
#  'DVM',
#  'DDS',
#  'DVM',
#  'MD',
#  'DDS',
#  'PhD',
#  'DDS',
#  'DDS',
#  'Jr.',
#  'Jr.',
#  'DVM',
#  'DDS',
#  'MD',
#  'MD',
#  'DVM',
#  'DDS',
#  'DVM',
#  'Jr.',
#  'MD',
#  'Jr.',
#  'MD',
#  'PhD',
#  'PhD',
#  'DDS',
#  'MD',
#  'DDS',
#  'DVM',
#  'Cox',
#  'DVM',
#  'MD',
#  'Jr.',
#  'MD',
#  'DDS',
#  'MD',
#  'MD',
#  'DDS',
#  'DDS',
# ...

# %%
#USE SET TO CRUSH THESE LONGLISTS

set(prefix)
# Out:
# {'Adam',
#  'Amy',
#  'Anna',
#  'Anne',
#  'Carl',
#  'Chad',
#  'Cody',
#  'Cory',
#  'Dale',
#  'Dana',
#  'Dawn',
#  'Dr.',
#  'Emma',
#  'Eric',
#  'Erik',
#  'Erin',
#  'Gail',
#  'Gary',
#  'Gina',
#  'Greg',
#  'Ian',
#  'Jill',
#  'Jodi',
#  'Joe',
#  'John',
#  'Jon',
#  'Jose',
#  'Judy',
#  'Kara',
#  'Kari',
#  'Kim',
#  'Kyle',
#  'Leah',
#  'Lisa',
#  'Lori',
#  'Luke',
#  'Lynn',
#  'Marc',
#  'Mark',
#  'Mary',
#  'Mike',
#  'Miss',
#  'Mr.',
#  'Mrs.',
#  'Ms.',
#  'Noah',
#  'Omar',
#  'Paul',
#  'Ruth',
#  'Ryan',
#  'Sara',
#  'Sean',
#  'Seth',
#  'Tara',
#  'Tina',
#  'Todd',
#  'Toni',
#  'Tony',
#  'Troy'}

# %%
set(suffix)
# Out:
# {'Cox',
#  'DDS',
#  'DVM',
#  'Day',
#  'II',
#  'III',
#  'IV',
#  'Jr.',
#  'Kim',
#  'Lee',
#  'Li',
#  'MD',
#  'PhD',
#  'Roy',
#  'V'}

# %%
prefixes_suffixes = ['Ms. ','Miss ', 'Mrs. ', 'Mr. ', 'Dr. ', ' DDS', ' DVM', ' MD', ' PhD']

#.STRIP() vs .REPLACE()
#.strip() will remove any of the characters put in its argument, if we put "Mrs.", the output will remove "M"s "r"s and "S"s
#.replace takes 2 arguments, the string to search for, and then the string to replace it with.
    #--since we are removing prefixes/suffixes that are followed/proceeded by whitespace, 
    # all .remove arguments need a whitespace to go
for i in prefixes_suffixes:
    students_df['student_name'] = students_df['student_name'].str.replace(i, '')

students_df
# Out:
# <ipython-input-35-f98d42195979>:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   students_df['student_name'] = students_df['student_name'].str.replace(i, '')
#        Student ID     student_name gender grade         school_name  \
# 0               0     Paul Bradley      M   9th   Huang High School
# 1               1     Victor Smith      M  12th   Huang High School
# 2               2  Kevin Rodriguez      M  12th   Huang High School
# 3               3    Richard Scott      M  12th   Huang High School
# 4               4       Bonnie Ray      F   9th   Huang High School
# ...           ...              ...    ...   ...                 ...
# 39165       39165     Donna Howard      F  12th  Thomas High School
# 39166       39166        Dawn Bell      F  10th  Thomas High School
# 39167       39167   Rebecca Tanner      F   9th  Thomas High School
# 39168       39168     Desiree Kidd      F  10th  Thomas High School
# ...

# %%
students_fixed = []
student_names = students_df['student_name'].tolist()

for name in student_names:
    if len(name.split()) >= 3:
        students_fixed.append(name)
students_fixed
# Out:
# ['Joseph Morales III',
#  'Xavier Bell II',
#  'David Miller Jr.',
#  'Reginald Garcia IV',
#  'Kevin Brown IV',
#  'William Washington Jr.',
#  'Juan Bryant II',
#  'Kenneth Paul Jr.',
#  'Scott Rivers III',
#  'Mark Myers Jr.',
#  'Michael Norton Jr.',
#  'Sean Pena Jr.',
#  'Cody Mueller Jr.',
#  'Mathew White Jr.',
#  'Jason Daugherty Jr.',
#  'Leonard Webster II',
#  'Michael Stein Jr.',
#  'Ryan Phillips Jr.',
#  'Allen Snyder Jr.',
#  'Calvin Williams Jr.',
#  'Ronald Torres Jr.',
#  'Gabriel Smith III',
#  'Brian Pitts Jr.',
#  'Bruce Thompson II',
#  'Jeremy Sanders II',
#  'Austin Johnson II',
#  'Bryan Conway Jr.',
#  'Ronald Moore II',
#  'Robert Garrison IV',
#  'William Gonzalez Jr.',
#  'Brian Matthews Jr.',
#  'Eric Richards Jr.',
#  'Kenneth Munoz Jr.',
#  'Jon Delgado Jr.',
#  'Andrew English Jr.',
#  'Raymond Cox Jr.',
#  'Jeffrey Mcclain Jr.',
#  'Brian Poole V',
#  'Jeffrey Kim II',
#  'Matthew Alexander Jr.',
#  'Kevin Reynolds Jr.',
#  'Jacob Skinner Jr.',
# ...

# %%
len(students_fixed)
# Out:
# 151
